# %% [markdown]
# <h1> Voyages Market Data API Example</h1>
# <h3> Run this example in :</h3>

# %% [markdown]
# [Colab](https://colab.research.google.com/github/SignalOceanSdk/SignalSDK/blob/master/docs/examples/jupyter/VoyagesMarketDataAPI/VoyagesMarketDataAPIExample.ipynb)

# %% [markdown]
# This Notbook demonstrates some examples of calling the basic API endpoints and the advanced endpoint that provides advanced filtering options.
#
# For the basic endpoints, you can use one of the following :
# * a specific imo
# * a specific voyage_id
# * a specific vessel_class_id
# * a specific vessel_type_id
#
# and use the following (optional) parameters : include_vessel_details, include_fixtures, include_lineups, include_positions, include_matched_fixture, include_labels
#
# The advanced endpoint provides you with more options, like :
#
# * imos: provide a list of IMOs
# * voyage_ids: provide a list of voyage IDs
# * vessel_class_ids: provide a list of vessel class IDs
# * trade_id
# * fixture_date_from, fixture_date_to, laycan_date_from, laycan_date_to: return market data for the given dates
# * charterer_ids_include, charterer_ids_exclude: include/exclude specific charterer IDs
# * cargo_type_ids_include, cargo_type_ids_exclude: include/exclude specific cargoes
# * sources_include, sources_exclude: include/exclude specific sources
# * include_vessel_details, include_fixtures, include_lineups, include_positions, include_matched_fixture, include_labels

# %% [markdown]
# <h3>Setup</h3>

# %% [markdown]
# Install the Signal Ocean SDK:

# %%
pip install signal-ocean

# %% [markdown]
# Import Voyages Market Data API and some additional libraries

# %%
import pandas as pd
import seaborn as sns

from signal_ocean import Connection
from signal_ocean.voyages_market_data import VoyagesMarketDataAPI

# %% [markdown]
# Fill in your personal SignalOcean API subscription key acquired <a href="https://apis.signalocean.com/profile" target="_blank">here</a> and open a connection:

# %%
signal_ocean_api_key = '' #replace with your subscription key

# %% [markdown]
# Create a connection

# %%
connection = Connection(signal_ocean_api_key)
api = VoyagesMarketDataAPI(connection)

# %% [markdown]
# <h3>Get market data including matched fixtures for a given vessel class (VLCCs)</h3>

# %%
result = api.get_voyage_market_data(vessel_class_id=84, include_matched_fixture = True, include_vessel_details = True, include_labels = True)

# %%
## Get return data into a dataframe
voyages_market_data = pd.DataFrame([r.__dict__ for r in result])
voyages_market_data.head()
# Out:
#                    id          voyage_id      imo  voyage_number vessel_name  \
# 0  MI8A2F75VED1A16F00  I8A2F75VED1A16F00  9056117             50   Symeon II
# 1  MI8B5F18VED1A16F00  I8B5F18VED1A16F00  9133848             69  S Tajimare
# 2  MI8B98DBVED179E200  I8B98DBVED179E200  9148635             34   DS Velvet
# 3  MI8BC5FEVED1944000  I8BC5FEVED1944000  9160190             41         Kym
# 4  MI8BC5FEVED1C8FC00  I8BC5FEVED1C8FC00  9160190             42         Kym
#
#    vessel_type_id vessel_type  vessel_class_id vessel_class  trade_id  trade  \
# 0               1      Tanker               84         VLCC         1  Crude
# 1               1      Tanker               84         VLCC         1  Crude
# 2               1      Tanker               84         VLCC         1  Crude
# 3               1      Tanker               84         VLCC         1  Crude
# 4               1      Tanker               84         VLCC         1  Crude
#
#    commercial_operator_id commercial_operator  deadweight  year_built  \
# 0                  1299.0  Polembros Shipping      277095        1994
# 1                   435.0     Dynacom Tankers      265539        1996
# 2                   510.0              Nayara      301438        1999
# 3                  1906.0     Embiricos Group      298324        1998
# 4                  1906.0     Embiricos Group      298324        1998
#
#                                      matched_fixture fixtures
# 0  MatchedFixture(fixture_status_id=1, fixture_st...     None
# 1  MatchedFixture(fixture_status_id=1, fixture_st...     None
# 2  MatchedFixture(fixture_status_id=1, fixture_st...     None
# 3  MatchedFixture(fixture_status_id=1, fixture_st...     None
# 4  MatchedFixture(fixture_status_id=1, fixture_st...     None

# %%
## Get matched fixtures seperately into a dataframe
matched_fixtures = pd.DataFrame([r.matched_fixture.__dict__ for r in result])
matched_fixtures.head()
# Out:
#    fixture_status_id fixture_status  charter_type_id charter_type  \
# 0                  1     FullyFixed                0       Voyage
# 1                  1     FullyFixed                0       Voyage
# 2                  1     FullyFixed                0       Voyage
# 3                  1     FullyFixed                0       Voyage
# 4                  1     FullyFixed                0       Voyage
#
#                       fixture_date  charterer_id  \
# 0 2017-11-24 18:43:41.780000+00:00         180.0
# 1 2018-01-09 16:31:15.390000+00:00         718.0
# 2        2017-12-15 00:00:00+00:00        2108.0
# 3        2017-11-17 00:00:00+00:00         180.0
# 4 2017-12-08 12:34:17.167000+00:00         180.0
#
#                                charterer               laycan_from  \
# 0                 Bharat Oman Refineries 2017-11-28 00:00:00+00:00
# 1                             Indian Oil 2018-01-16 00:00:00+00:00
# 2  Mangalore Refinery and Petrochemicals 2017-12-27 00:00:00+00:00
# 3                 Bharat Oman Refineries 2017-12-03 00:00:00+00:00
# 4                 Bharat Oman Refineries 2017-12-29 00:00:00+00:00
#
#                   laycan_to  load_geo_id  ... redelivery_to_taxonomy_id  \
# 0 2017-11-28 23:59:59+00:00      24777.0  ...                      None
# 1 2018-01-17 23:59:59+00:00      24777.0  ...                      None
# 2 2017-12-28 23:59:59+00:00      24777.0  ...                      None
# 3 2017-12-03 23:59:59+00:00      24777.0  ...                      None
# 4 2017-12-29 23:59:59+00:00      24777.0  ...                      None
#
#    redelivery_to_taxonomy user_entries  full_fixtures partial_fixtures  \
# 0                    None            0              2                0
# 1                    None            0              8                0
# 2                    None            0              1                0
# 3                    None            0              2                0
# 4                    None            0              8                0
#
#    is_coa is_owners_option  is_hold is_fio    sources
# 0    None             None     None   None  (TI app,)
# 1    None             None     None   None  (TI app,)
# 2    None             None     None   None  (TI app,)
# 3    None             None     None   None  (TI app,)
# 4    None             None     None   None  (TI app,)
#
# [5 rows x 57 columns]

# %% [markdown]
# <h3>Get market data including fixtures for a given vessel class (VLCCs)</h3>

# %%
result = api.get_voyage_market_data(vessel_class_id=84, include_fixtures = True, include_vessel_details = True,
        include_labels = True)

# %%
## Get return data into a dataframe
voyages_market_data = pd.DataFrame([r.__dict__ for r in result])
voyages_market_data.head()
# Out:
#                    id          voyage_id      imo  voyage_number vessel_name  \
# 0  MI8A2F75VED1A16F00  I8A2F75VED1A16F00  9056117             50   Symeon II
# 1  MI8B5F18VED1A16F00  I8B5F18VED1A16F00  9133848             69  S Tajimare
# 2  MI8B98DBVED179E200  I8B98DBVED179E200  9148635             34   DS Velvet
# 3  MI8B98DBVED1C8FC00  I8B98DBVED1C8FC00  9148635             35   DS Velvet
# 4  MI8BC5FEVED1944000  I8BC5FEVED1944000  9160190             41         Kym
#
#    vessel_type_id vessel_type  vessel_class_id vessel_class  trade_id  trade  \
# 0               1      Tanker               84         VLCC         1  Crude
# 1               1      Tanker               84         VLCC         1  Crude
# 2               1      Tanker               84         VLCC         1  Crude
# 3               1      Tanker               84         VLCC         1  Crude
# 4               1      Tanker               84         VLCC         1  Crude
#
#    commercial_operator_id commercial_operator  deadweight  year_built  \
# 0                  1299.0  Polembros Shipping      277095        1994
# 1                   435.0     Dynacom Tankers      265539        1996
# 2                   510.0              Nayara      301438        1999
# 3                   248.0       Carl F Peters      301438        1999
# 4                  1906.0     Embiricos Group      298324        1998
#
#   matched_fixture                                           fixtures
# 0            None  (Fixture(fixture_id=3546721, is_matched=True, ...
# 1            None  (Fixture(fixture_id=6250780, is_matched=True, ...
# 2            None  (Fixture(fixture_id=6285170, is_matched=True, ...
# 3            None  (Fixture(fixture_id=6353657, is_matched=None, ...
# 4            None  (Fixture(fixture_id=3533624, is_matched=True, ...

# %%
## Get fixtures seperately into a dataframe
fixtures = pd.DataFrame(f.__dict__ for fixtures in voyages_market_data['fixtures'].dropna() for f in fixtures)
fixtures.head()
# Out:
#    fixture_id is_matched is_load_matched is_discharge_matched  \
# 0     3546721       True            True                 True
# 1     4151663       True            True                 True
# 2     6250780       True            True                 True
# 3     6251766       True            True                 True
# 4     6253238       True            True                 True
#
#    fixture_status_id fixture_status
# 0                NaN           None
# 1                NaN           None
# 2                0.0         OnSubs
# 3                0.0         OnSubs
# 4                0.0         OnSubs

# %%
# Expand the dataframe to have one row per fixture
voyages_market_data=voyages_market_data.explode('fixtures').reset_index(drop=True)
voyages_market_data.head()
# Out:
#                    id          voyage_id      imo  voyage_number vessel_name  \
# 0  MI8A2F75VED1A16F00  I8A2F75VED1A16F00  9056117             50   Symeon II
# 1  MI8A2F75VED1A16F00  I8A2F75VED1A16F00  9056117             50   Symeon II
# 2  MI8B5F18VED1A16F00  I8B5F18VED1A16F00  9133848             69  S Tajimare
# 3  MI8B5F18VED1A16F00  I8B5F18VED1A16F00  9133848             69  S Tajimare
# 4  MI8B5F18VED1A16F00  I8B5F18VED1A16F00  9133848             69  S Tajimare
#
#    vessel_type_id vessel_type  vessel_class_id vessel_class  trade_id  trade  \
# 0               1      Tanker               84         VLCC         1  Crude
# 1               1      Tanker               84         VLCC         1  Crude
# 2               1      Tanker               84         VLCC         1  Crude
# 3               1      Tanker               84         VLCC         1  Crude
# 4               1      Tanker               84         VLCC         1  Crude
#
#    commercial_operator_id commercial_operator  deadweight  year_built  \
# 0                  1299.0  Polembros Shipping      277095        1994
# 1                  1299.0  Polembros Shipping      277095        1994
# 2                   435.0     Dynacom Tankers      265539        1996
# 3                   435.0     Dynacom Tankers      265539        1996
# 4                   435.0     Dynacom Tankers      265539        1996
#
#   matched_fixture                                           fixtures
# 0            None  Fixture(fixture_id=3546721, is_matched=True, i...
# 1            None  Fixture(fixture_id=4151663, is_matched=True, i...
# 2            None  Fixture(fixture_id=6250780, is_matched=True, i...
# 3            None  Fixture(fixture_id=6251766, is_matched=True, i...
# 4            None  Fixture(fixture_id=6253238, is_matched=True, i...

# %% [markdown]
# <h3>Get market data for a given Vessel</h3>

# %%
result = api.get_voyage_market_data(imo = 9890965, include_fixtures = True, include_matched_fixture = True, include_labels = True)

# %%
## Get return data into a dataframe
voyages_market_data = pd.DataFrame([r.__dict__ for r in result])

# %% [markdown]
# <h3>Get market data using the advanced endpoint</h3>

# %%
# Get market data for vessels classes [84, 85], with laycan date from '2023-01-01'
result = api.get_voyage_market_data_advanced(vessel_class_ids = [84, 85], include_vessel_details = True,
        include_fixtures = True, include_lineups = True, include_positions = True, include_matched_fixture = True,
        include_labels = True, laycan_date_from = '2023-01-01')

# %%
voyages_market_data = pd.DataFrame([r.__dict__ for r in result])
voyages_market_data.head()
# Out:
#                    id          voyage_id      imo  voyage_number  \
# 0  MI8C9C3CVEDB359500  I8C9C3CVEDB359500  9215036            142
# 1  MI8C9C3CVEDB5D2200  I8C9C3CVEDB5D2200  9215036            143
# 2  MI8D1456VEDB359500  I8D1456VEDB359500  9245782             78
# 3  MI8D1E99VEDB359500  I8D1E99VEDB359500  9248409             83
# 4  MI8D40BDVEDB0E0800  I8D40BDVEDB0E0800  9257149             75
#
#       vessel_name  vessel_type_id vessel_type  vessel_class_id vessel_class  \
# 0           Chafa               1      Tanker               85      Suezmax
# 1           Chafa               1      Tanker               85      Suezmax
# 2   Cosglory Lake               1      Tanker               84         VLCC
# 3    Seoul Spirit               1      Tanker               85      Suezmax
# 4  Elizabeth I.A.               1      Tanker               84         VLCC
#
#    trade_id  trade  commercial_operator_id       commercial_operator  \
# 0         1  Crude                    2386             LMCS Maritime
# 1         1  Crude                    2386             LMCS Maritime
# 2         1  Crude                     356                     COSCO
# 3         1  Crude                    1663               Teekay Corp
# 4         1  Crude                     917  Maran Tankers Management
#
#    deadweight  year_built                                    matched_fixture  \
# 0      150678        2001  MatchedFixture(fixture_status_id=1, fixture_st...
# 1      150678        2001  MatchedFixture(fixture_status_id=1, fixture_st...
# 2      299145        2003  MatchedFixture(fixture_status_id=1, fixture_st...
# 3      159966        2005  MatchedFixture(fixture_status_id=1, fixture_st...
# 4      306229        2004  MatchedFixture(fixture_status_id=1, fixture_st...
#
#                                             fixtures
# 0  (Fixture(fixture_id=104321600, is_matched=True...
# 1  (Fixture(fixture_id=105207913, is_matched=True...
# 2  (Fixture(fixture_id=105504298, is_matched=True...
# 3  (Fixture(fixture_id=105311802, is_matched=True...
# 4  (Fixture(fixture_id=104633101, is_matched=True...

# %%
matched_fixtures = pd.DataFrame([r.matched_fixture.__dict__ for r in result])
matched_fixtures.head()
# Out:
#    fixture_status_id fixture_status  charter_type_id charter_type  \
# 0                  1     FullyFixed                0       Voyage
# 1                  1     FullyFixed                0       Voyage
# 2                  1     FullyFixed                0       Voyage
# 3                  1     FullyFixed                0       Voyage
# 4                  1     FullyFixed                0       Voyage
#
#                fixture_date  charterer_id               charterer  \
# 0 2022-12-19 17:00:42+00:00         180.0  Bharat Oman Refineries
# 1 2023-01-06 14:40:33+00:00         718.0              Indian Oil
# 2 2023-01-10 16:57:45+00:00           NaN                    None
# 3 2023-01-09 09:59:01+00:00        1237.0                 Petraco
# 4 2022-12-22 18:03:02+00:00        1928.0                  Unipec
#
#                 laycan_from                 laycan_to  load_geo_id  ...  \
# 0 2023-01-05 00:00:00+00:00 2023-01-05 00:00:00+00:00         3778  ...
# 1 2023-01-26 00:00:00+00:00 2023-01-26 00:00:00+00:00         3778  ...
# 2 2023-01-23 00:00:00+00:00 2023-01-23 00:00:00+00:00        24777  ...
# 3 2023-01-25 00:00:00+00:00 2023-01-25 00:00:00+00:00         9763  ...
# 4 2023-01-04 00:00:00+00:00 2023-01-04 00:00:00+00:00        24777  ...
#
#   redelivery_to_taxonomy_id  redelivery_to_taxonomy user_entries  \
# 0                      None                    None            0
# 1                      None                    None            0
# 2                      None                    None            0
# 3                      None                    None            0
# 4                      None                    None            0
#
#    full_fixtures partial_fixtures  is_coa is_owners_option  is_hold is_fio  \
# 0              8                0    None             None     None   None
# 1             10                0    None             None     None   None
# 2              2                0    None             None     None   None
# 3              4                8    None             None     None   None
# 4              2                0    None             None     None   None
#
#                                              sources
# 0  (galbraiths.co.uk, ssysin.com.sg, ssy.co.uk, s...
# 1  (southportmaritime.com, ssy.co.uk, galbraiths....
# 2                   (galbraiths.co.uk, Signal Ocean)
# 3  (southportmaritime.com, ssy.co.uk, Signal Ocea...
# 4              (Signal Ocean, southportmaritime.com)
#
# [5 rows x 57 columns]
