# %% [markdown]
# # Companies API Example

# %% [markdown]
# ## Setup
# Install the Signal Ocean SDK:
# ```
# pip install signal-ocean
# ```
# And put your API key in a `SIGNAL_OCEAN_API_KEY` environment variable.

# %%
from signal_ocean.companies import CompaniesAPI
import pandas as pd

# %% [markdown]
# ## Call the Companies API
# The Companies API retrieves information about companies.

# %%
api = CompaniesAPI()

# %% [markdown]
# #### Get company by id

# %%
company_id = 1926
c = api.get_company(company_id)
print(f'Company {company_id}: {c.company_name} ({c.website})')
# Out:
# Company 1926: Signal Maritime (http://signalmaritime.com/)

# %% [markdown]
# #### Get details for all companies

# %%
companies = api.get_companies()

# %%
len(companies)
# Out:
# 4108

# %%
df = pd.DataFrame([x.__dict__ for x in companies])

# %%
df.columns
# Out:
# Index(['id', 'updated_date', 'company_name', 'website', 'fleet_list',
#        'synonyms', 'charterer_vessel_types',
#        'commercial_operator_vessel_types', 'geo_asset_owner_vessel_types',
#        'broker_vessel_types', 'port_agent_vessel_types', 'parent_company_id',
#        'children_companies_ids'],
#       dtype='object')

# %%
df.head(10)
# Out:
#    id        updated_date                        company_name  \
# 0   3 2018-06-22 14:09:27                     Abiola Shipping
# 1   5 2018-08-08 09:39:21                           Abu Dhabi
# 2   6 2016-10-31 16:32:56            Abu Dhabi Gas Industries
# 3   7 2016-10-31 16:32:56  Abu Dhabi Marine Operating Company
# 4   8 2016-10-31 16:32:56               Abu Dhabi Oil Company
# 5   9 2016-10-31 16:39:13      Abu Dubai Oil Refining Company
# 6  10 2016-10-31 16:32:56                              Aca Sa
# 7  12 2016-10-31 16:32:56                         Ace Tankers
# 8  13 2016-10-31 16:32:56                    Aceitera General
# 9  16 2016-12-23 17:55:50                        Achema Group
#
#                                              website  \
# 0  http://www.equasis.org/EquasisWeb/restricted/C...
# 1        https://adnoc.ae/adnoc-onshore/notification
# 2            http://www.gasco.ae/en/Pages/Index.aspx
# 3  http://www.adma-opco.com/en/home/index.aspx?&P...
# 4                         http://adocauh.cts-co.net/
# 5                  http://www.takreer.com/index.html
# 6                            http://www.acacitv.com/
# 7                        http://www.ace-tankers.com/
# 8                    https://www.agd.com.ar/en/home/
# 9          http://www.achemosgrupe.lt/en/who-we-are/
#
#                               fleet_list     synonyms charterer_vessel_types  \
# 0                                   None         None                   None
# 1                                   None         None                   None
# 2                                   None      [Gasco]                   None
# 3                                   None  [ADMA-OPCO]                   None
# 4                                   None       [ADOC]               [Tanker]
# 5                                   None    [TAKREER]                   None
# 6                                   None         None                   None
# 7  http://www.ace-tankers.com/fleet.html         None                   None
# 8                                   None        [AGD]               [Tanker]
# 9                                   None         None                   None
#
#   commercial_operator_vessel_types geo_asset_owner_vessel_types  \
# 0                         [Tanker]                         None
# 1                             None                     [Tanker]
# 2                             None                     [Tanker]
# 3                             None                     [Tanker]
# 4                             None                     [Tanker]
# 5                             None                     [Tanker]
# 6                             None                     [Tanker]
# 7                         [Tanker]                         None
# 8                             None                         None
# 9                             None                     [Tanker]
#
#   broker_vessel_types port_agent_vessel_types  parent_company_id  \
# 0                None                    None                NaN
# 1                None                    None                NaN
# 2                None                    None                NaN
# 3                None                    None                NaN
# 4                None                    None                NaN
# 5                None                    None                NaN
# 6                None                    None                NaN
# 7                None                    None                NaN
# 8                None                    None                NaN
# 9                None                    None                NaN
#
#   children_companies_ids
# 0                   None
# 1                   None
# 2                   None
# 3                   None
# 4                   None
# 5                   None
# 6                   None
# 7                   None
# 8                   None
# 9                   None

# %% [markdown]
# #### Get all companies the name of which contains the term Maritime

# %%
companies = api.get_companies('maritime')

# %%
len(companies)
# Out:
# 169

# %%
df = pd.DataFrame([x.__dict__ for x in companies])

# %%
df.head(10)
# Out:
#     id        updated_date                       company_name  \
# 0   43 2016-10-31 16:32:56           Al Rekab Global Maritime
# 1   53 2019-07-30 11:25:15                      Alma Maritime
# 2   66 2016-10-31 16:32:56                     Alvan Maritime
# 3   81 2016-10-31 16:32:56                    Andros Maritime
# 4   95 2018-05-11 08:29:26  Arab Maritime Petroleum Transport
# 5  118 2018-06-27 12:31:03                Associated Maritime
# 6  124 2016-10-31 16:32:56                     Atlas Maritime
# 7  168 2016-10-31 16:32:56                  Belavero Maritime
# 8  203 2016-10-31 16:32:56                     Boray Maritime
# 9  226 2018-07-06 13:08:51                 Byzantine Maritime
#
#                                              website  \
# 0  http://marbnet.com/directory/listing/al-rekab-...
# 1                       http://www.almamaritime.com/
# 2     https://opencorporates.com/companies/pa/744162
# 3  http://www.logisticscout.com/company-andros-ma...
# 4                              http://www.amptc.net/
# 5   http://www.hkmw.com.hk/webappen/main.asp?sid=455
# 6                       http://www.atlasmaritime.eu/
# 7  http://marbnet.com/directory/listing/belavero-...
# 8  http://www.world-ships.com/company/df76f52c5e4...
# 9                                 http://www.bmc.gr/
#
#                                           fleet_list synonyms  \
# 0                                               None     None
# 1  http://www.almamaritime.com/content/fleet/004/...     None
# 2                                               None     None
# 3                                               None     None
# 4                              http://www.amptc.net/  [AMPTC]
# 5  http://www.hkmw.com.hk/webappen/main3.asp?sid=482   [AMCL]
# 6                  http://www.atlasmaritime.eu/fleet     None
# 7                                               None     None
# 8                                               None     None
# 9                  http://www.bmc.gr/fleet/Fleet.htm    [BMC]
#
#   charterer_vessel_types commercial_operator_vessel_types  \
# 0                   None                         [Tanker]
# 1                   None                    [Tanker, Dry]
# 2                   None                         [Tanker]
# 3                   None                         [Tanker]
# 4                   None                         [Tanker]
# 5                   None                    [Tanker, Dry]
# 6               [Tanker]                             None
# 7                   None                         [Tanker]
# 8                   None                         [Tanker]
# 9                   None                    [Tanker, Dry]
#
#   geo_asset_owner_vessel_types broker_vessel_types port_agent_vessel_types  \
# 0                         None                None                    None
# 1                         None                None                    None
# 2                         None                None                    None
# 3                         None                None                    None
# 4                         None                None                    None
# 5                         None                None                    None
# 6                         None                None                    None
# 7                         None                None                    None
# 8                         None                None                    None
# 9                         None                None                    None
#
#    parent_company_id children_companies_ids
# 0                NaN                   None
# 1                NaN                   None
# 2                NaN                   None
# 3                NaN                   None
# 4                NaN                   None
# 5                NaN                  [286]
# 6                NaN                   None
# 7                NaN                   None
# 8                NaN                   None
# 9                NaN                   None

# %%
df[df['company_name'].str.startswith('Signal')]
# Out:
#       id        updated_date     company_name                     website  \
# 61  1926 2018-10-08 12:51:54  Signal Maritime  http://signalmaritime.com/
#
#                     fleet_list synonyms charterer_vessel_types  \
# 61  http://signalmaritime.com/     None                   None
#
#    commercial_operator_vessel_types geo_asset_owner_vessel_types  \
# 61                    [Tanker, Dry]                         None
#
#    broker_vessel_types port_agent_vessel_types  parent_company_id  \
# 61                None                    None                NaN
#
#    children_companies_ids
# 61                   None
